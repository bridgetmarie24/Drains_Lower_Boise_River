# %% [markdown]
# # **Subset geospatial data and calculate landscape metrics**
#
# By Bridget Bittmann
#
# Date created: March 14, 2022
#
# Date editted: March 28, 2022

# %%
## IMPORT PACKAGES ##

import numpy as np #basic computation
# !pip install geopandas
import geopandas as gpd #geopandas for .shp
import pandas as pd #to create dataframes and export .csv
# !pip install rasterio
import rasterio as rso #import GeoTiff files
from rasterio.mask import mask #to crop data to a boundary
from rasterio.plot import show #to plot the image
from rasterio.crs import CRS
from shapely.ops import unary_union #creates boundary of shapefile
import json #imports metadata
# !pip install rioxarray #to clip rasters to a .shp file
import rioxarray as rxr
from rasterio.warp import calculate_default_transform, reproject, Resampling
# !pip install pylandstats
import pylandstats #to perform landscape metrics
from pylandstats import landscape
from pylandstats import SpatioTemporalAnalysis #to calculate landscape metrics through time
import glob
import os

# %%
from google.colab import drive 
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
## NAVIGATE TO YOUR DIRECTORY ##
# %cd gdrive/MyDrive/
# %ls
# Out:
# /content/gdrive/MyDrive
# 'BSU Year 1'/                                'Grad Logistics'/
#  Colab/                                      'Hydro Summer Meet up'/
# 'Colab Notebooks'/                           'PODS for Bridgett.kmz'
#  Drainage_analysis/                           spatial_colab/
#  GMT20220318-210220_Recording_1920x1080.mp4  'Thesis Papers'/

# %%
## ---------------------- ##
## SUBSET GEOSPATIAL DATA ##
## ---------------------- ##

shp_file = gpd.read_file('Drainage_analysis/datasets/drain_delineation/Drains_Merge_07072022.shp') #open shapefile
names = shp_file['Name']
print(names)
files = glob.glob('spatial_colab/datasets/lcmap_files/*.tiff') #get all the years of cdl imagery
data =[]
for i in range(len(files)):
  data.append(rso.open(files[i])) #open cdl image and append to a list
shp = shp_file.to_crs(data[1].crs) #reproject the shp file to same projection
years = np.arange(1987, 2021) #years of LCMAP data
collection = []
for i in range(len(shp)):
  for n in range(len(years)):
    dataset = data[n]
    year_out = dataset.name[44:48]
    extent = gpd.GeoSeries(shp['geometry'][i]) #get the geometry from shapefile
    coords = [json.loads(extent.to_json())['features'][0]['geometry']] #gets coordinates for rasterio input
    out_img, out_transform = mask(dataset=data[n], shapes=coords, crop=True, nodata=0) #crop the data to the shapefile
    out_meta = data[n].meta.copy()
    out_meta.update({"driver": "GTiff",
                     "height": out_img.shape[1],
                     "width": out_img.shape[2],
                     "transform": out_transform})
    # Merge original file name with init_landcover to denote that it is the initial land cover data for Janus
    in_file = files[n]
    out_filename = os.path.join('Drainage_analysis/datasets/land_use/'+names[i]+'_'+year_out+'.tif') #create a file name to export to
    print(out_filename)
    # Save clipped land cover coverage THIS WILL OVERWRITE FILES
    out_tiff = rso.open(out_filename, 'w', **out_meta)
    out_tiff.write(np.squeeze(out_img, 0), 1)
    out_tiff.close()
    collection.append(out_img)
# Out:
# 0                West Hartley
# 1              Sand Run Gulch
# 2                 Eagle Drain
# 3                 Mason Drain
# 4                 Mason Creek
# 5          East Hartley Drain
# 6                Willow Creek
# 7                Conway Gulch
# 8                ThurmanDrain
# 9             North Middleton
# 10            South Middleton
# 11               Indian Creek
# 12    Drainage District No. 3
# 13         Fifteen Mile Creek
# 14                Dixie drain
# Name: Name, dtype: object
# Drainage_analysis/datasets/land_use/West Hartley_1987.tif
# Drainage_analysis/datasets/land_use/West Hartley_1986.tif
# Drainage_analysis/datasets/land_use/West Hartley_1989.tif
# Drainage_analysis/datasets/land_use/West Hartley_1988.tif
# Drainage_analysis/datasets/land_use/West Hartley_1990.tif
# Drainage_analysis/datasets/land_use/West Hartley_1992.tif
# Drainage_analysis/datasets/land_use/West Hartley_1991.tif
# Drainage_analysis/datasets/land_use/West Hartley_1993.tif
# Drainage_analysis/datasets/land_use/West Hartley_1994.tif
# Drainage_analysis/datasets/land_use/West Hartley_1995.tif
# Drainage_analysis/datasets/land_use/West Hartley_1996.tif
# Drainage_analysis/datasets/land_use/West Hartley_1997.tif
# Drainage_analysis/datasets/land_use/West Hartley_1999.tif
# Drainage_analysis/datasets/land_use/West Hartley_1998.tif
# Drainage_analysis/datasets/land_use/West Hartley_2000.tif
# Drainage_analysis/datasets/land_use/West Hartley_2001.tif
# Drainage_analysis/datasets/land_use/West Hartley_2002.tif
# Drainage_analysis/datasets/land_use/West Hartley_2003.tif
# Drainage_analysis/datasets/land_use/West Hartley_2004.tif
# Drainage_analysis/datasets/land_use/West Hartley_2005.tif
# Drainage_analysis/datasets/land_use/West Hartley_2006.tif
# Drainage_analysis/datasets/land_use/West Hartley_2007.tif
# Drainage_analysis/datasets/land_use/West Hartley_2009.tif
# Drainage_analysis/datasets/land_use/West Hartley_2008.tif
# Drainage_analysis/datasets/land_use/West Hartley_2010.tif
# Drainage_analysis/datasets/land_use/West Hartley_2012.tif
# Drainage_analysis/datasets/land_use/West Hartley_2011.tif
# Drainage_analysis/datasets/land_use/West Hartley_2013.tif
# Drainage_analysis/datasets/land_use/West Hartley_2015.tif
# Drainage_analysis/datasets/land_use/West Hartley_2014.tif
# Drainage_analysis/datasets/land_use/West Hartley_2016.tif
# Drainage_analysis/datasets/land_use/West Hartley_2017.tif
# Drainage_analysis/datasets/land_use/West Hartley_2018.tif
# Drainage_analysis/datasets/land_use/West Hartley_2020.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1987.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1986.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1989.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1988.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1990.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1992.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1991.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1993.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1994.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1995.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1996.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1997.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1999.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_1998.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2000.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2001.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2002.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2003.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2004.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2005.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2006.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2007.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2009.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2008.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2010.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2012.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2011.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2013.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2015.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2014.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2016.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2017.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2018.tif
# Drainage_analysis/datasets/land_use/Sand Run Gulch_2020.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1987.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1986.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1989.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1988.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1990.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1992.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1991.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1993.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1994.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1995.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1996.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1997.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1999.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_1998.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2000.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2001.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2002.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2003.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2004.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2005.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2006.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2007.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2009.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2008.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2010.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2012.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2011.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2013.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2015.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2014.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2016.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2017.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2018.tif
# Drainage_analysis/datasets/land_use/Eagle Drain_2020.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1987.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1986.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1989.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1988.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1990.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1992.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1991.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1993.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1994.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1995.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1996.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1997.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1999.tif
# Drainage_analysis/datasets/land_use/Mason Drain_1998.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2000.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2001.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2002.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2003.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2004.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2005.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2006.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2007.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2009.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2008.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2010.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2012.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2011.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2013.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2015.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2014.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2016.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2017.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2018.tif
# Drainage_analysis/datasets/land_use/Mason Drain_2020.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1987.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1986.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1989.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1988.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1990.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1992.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1991.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1993.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1994.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1995.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1996.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1997.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1999.tif
# Drainage_analysis/datasets/land_use/Mason Creek_1998.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2000.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2001.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2002.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2003.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2004.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2005.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2006.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2007.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2009.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2008.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2010.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2012.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2011.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2013.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2015.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2014.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2016.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2017.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2018.tif
# Drainage_analysis/datasets/land_use/Mason Creek_2020.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1987.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1986.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1989.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1988.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1990.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1992.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1991.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1993.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1994.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1995.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1996.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1997.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1999.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_1998.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2000.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2001.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2002.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2003.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2004.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2005.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2006.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2007.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2009.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2008.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2010.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2012.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2011.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2013.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2015.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2014.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2016.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2017.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2018.tif
# Drainage_analysis/datasets/land_use/East Hartley Drain_2020.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1987.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1986.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1989.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1988.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1990.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1992.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1991.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1993.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1994.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1995.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1996.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1997.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1999.tif
# Drainage_analysis/datasets/land_use/Willow Creek_1998.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2000.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2001.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2002.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2003.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2004.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2005.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2006.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2007.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2009.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2008.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2010.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2012.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2011.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2013.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2015.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2014.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2016.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2017.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2018.tif
# Drainage_analysis/datasets/land_use/Willow Creek_2020.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1987.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1986.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1989.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1988.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1990.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1992.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1991.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1993.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1994.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1995.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1996.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1997.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1999.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_1998.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2000.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2001.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2002.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2003.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2004.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2005.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2006.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2007.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2009.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2008.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2010.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2012.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2011.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2013.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2015.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2014.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2016.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2017.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2018.tif
# Drainage_analysis/datasets/land_use/Conway Gulch_2020.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1987.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1986.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1989.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1988.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1990.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1992.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1991.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1993.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1994.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1995.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1996.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1997.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1999.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_1998.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2000.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2001.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2002.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2003.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2004.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2005.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2006.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2007.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2009.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2008.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2010.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2012.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2011.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2013.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2015.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2014.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2016.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2017.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2018.tif
# Drainage_analysis/datasets/land_use/ThurmanDrain_2020.tif
# Drainage_analysis/datasets/land_use/North Middleton_1987.tif
# Drainage_analysis/datasets/land_use/North Middleton_1986.tif
# Drainage_analysis/datasets/land_use/North Middleton_1989.tif
# Drainage_analysis/datasets/land_use/North Middleton_1988.tif
# Drainage_analysis/datasets/land_use/North Middleton_1990.tif
# Drainage_analysis/datasets/land_use/North Middleton_1992.tif
# Drainage_analysis/datasets/land_use/North Middleton_1991.tif
# Drainage_analysis/datasets/land_use/North Middleton_1993.tif
# Drainage_analysis/datasets/land_use/North Middleton_1994.tif
# Drainage_analysis/datasets/land_use/North Middleton_1995.tif
# Drainage_analysis/datasets/land_use/North Middleton_1996.tif
# Drainage_analysis/datasets/land_use/North Middleton_1997.tif
# Drainage_analysis/datasets/land_use/North Middleton_1999.tif
# Drainage_analysis/datasets/land_use/North Middleton_1998.tif
# Drainage_analysis/datasets/land_use/North Middleton_2000.tif
# Drainage_analysis/datasets/land_use/North Middleton_2001.tif
# Drainage_analysis/datasets/land_use/North Middleton_2002.tif
# Drainage_analysis/datasets/land_use/North Middleton_2003.tif
# Drainage_analysis/datasets/land_use/North Middleton_2004.tif
# Drainage_analysis/datasets/land_use/North Middleton_2005.tif
# Drainage_analysis/datasets/land_use/North Middleton_2006.tif
# Drainage_analysis/datasets/land_use/North Middleton_2007.tif
# Drainage_analysis/datasets/land_use/North Middleton_2009.tif
# Drainage_analysis/datasets/land_use/North Middleton_2008.tif
# Drainage_analysis/datasets/land_use/North Middleton_2010.tif
# Drainage_analysis/datasets/land_use/North Middleton_2012.tif
# Drainage_analysis/datasets/land_use/North Middleton_2011.tif
# Drainage_analysis/datasets/land_use/North Middleton_2013.tif
# Drainage_analysis/datasets/land_use/North Middleton_2015.tif
# Drainage_analysis/datasets/land_use/North Middleton_2014.tif
# Drainage_analysis/datasets/land_use/North Middleton_2016.tif
# Drainage_analysis/datasets/land_use/North Middleton_2017.tif
# Drainage_analysis/datasets/land_use/North Middleton_2018.tif
# Drainage_analysis/datasets/land_use/North Middleton_2020.tif
# Drainage_analysis/datasets/land_use/South Middleton_1987.tif
# Drainage_analysis/datasets/land_use/South Middleton_1986.tif
# Drainage_analysis/datasets/land_use/South Middleton_1989.tif
# Drainage_analysis/datasets/land_use/South Middleton_1988.tif
# Drainage_analysis/datasets/land_use/South Middleton_1990.tif
# Drainage_analysis/datasets/land_use/South Middleton_1992.tif
# Drainage_analysis/datasets/land_use/South Middleton_1991.tif
# Drainage_analysis/datasets/land_use/South Middleton_1993.tif
# Drainage_analysis/datasets/land_use/South Middleton_1994.tif
# Drainage_analysis/datasets/land_use/South Middleton_1995.tif
# Drainage_analysis/datasets/land_use/South Middleton_1996.tif
# Drainage_analysis/datasets/land_use/South Middleton_1997.tif
# Drainage_analysis/datasets/land_use/South Middleton_1999.tif
# Drainage_analysis/datasets/land_use/South Middleton_1998.tif
# Drainage_analysis/datasets/land_use/South Middleton_2000.tif
# Drainage_analysis/datasets/land_use/South Middleton_2001.tif
# Drainage_analysis/datasets/land_use/South Middleton_2002.tif
# Drainage_analysis/datasets/land_use/South Middleton_2003.tif
# Drainage_analysis/datasets/land_use/South Middleton_2004.tif
# Drainage_analysis/datasets/land_use/South Middleton_2005.tif
# Drainage_analysis/datasets/land_use/South Middleton_2006.tif
# Drainage_analysis/datasets/land_use/South Middleton_2007.tif
# Drainage_analysis/datasets/land_use/South Middleton_2009.tif
# Drainage_analysis/datasets/land_use/South Middleton_2008.tif
# Drainage_analysis/datasets/land_use/South Middleton_2010.tif
# Drainage_analysis/datasets/land_use/South Middleton_2012.tif
# Drainage_analysis/datasets/land_use/South Middleton_2011.tif
# Drainage_analysis/datasets/land_use/South Middleton_2013.tif
# Drainage_analysis/datasets/land_use/South Middleton_2015.tif
# Drainage_analysis/datasets/land_use/South Middleton_2014.tif
# Drainage_analysis/datasets/land_use/South Middleton_2016.tif
# Drainage_analysis/datasets/land_use/South Middleton_2017.tif
# Drainage_analysis/datasets/land_use/South Middleton_2018.tif
# Drainage_analysis/datasets/land_use/South Middleton_2020.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1987.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1986.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1989.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1988.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1990.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1992.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1991.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1993.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1994.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1995.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1996.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1997.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1999.tif
# Drainage_analysis/datasets/land_use/Indian Creek_1998.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2000.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2001.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2002.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2003.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2004.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2005.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2006.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2007.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2009.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2008.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2010.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2012.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2011.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2013.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2015.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2014.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2016.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2017.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2018.tif
# Drainage_analysis/datasets/land_use/Indian Creek_2020.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1987.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1986.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1989.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1988.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1990.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1992.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1991.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1993.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1994.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1995.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1996.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1997.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1999.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_1998.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2000.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2001.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2002.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2003.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2004.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2005.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2006.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2007.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2009.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2008.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2010.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2012.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2011.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2013.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2015.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2014.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2016.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2017.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2018.tif
# Drainage_analysis/datasets/land_use/Drainage District No. 3_2020.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1987.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1986.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1989.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1988.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1990.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1992.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1991.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1993.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1994.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1995.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1996.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1997.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1999.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_1998.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2000.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2001.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2002.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2003.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2004.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2005.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2006.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2007.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2009.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2008.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2010.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2012.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2011.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2013.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2015.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2014.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2016.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2017.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2018.tif
# Drainage_analysis/datasets/land_use/Fifteen Mile Creek_2020.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1987.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1986.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1989.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1988.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1990.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1992.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1991.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1993.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1994.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1995.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1996.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1997.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1999.tif
# Drainage_analysis/datasets/land_use/Dixie drain_1998.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2000.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2001.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2002.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2003.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2004.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2005.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2006.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2007.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2009.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2008.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2010.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2012.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2011.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2013.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2015.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2014.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2016.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2017.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2018.tif
# Drainage_analysis/datasets/land_use/Dixie drain_2020.tif

# %%
## ---------------------------------------- ##
## Import multiple rasters into PyLandStats ##
## ---------------------------------------- ##
years = np.arange(1987,2021)
temporal_group = []
for i in names:
  files= sorted(glob.glob('Drainage_analysis/datasets/land_use/'+i+'_*.tif')) #name for all the csv files
  sta = SpatioTemporalAnalysis(files, dates=years, nodata=0) #import all CDL rasters and mask
  temporal_group.append(sta)

# %%
# ------------------------------- #
# CALCULATE THE CLASS PROPORTIONS #
# ------------------------------- #

proportions = []

for i in range(len(names)):
  df = SpatioTemporalAnalysis.compute_class_metrics_df(temporal_group[i], metrics=['proportion_of_landscape'])
  df.to_csv('Drainage_analysis/datasets/land_use/proportions/'+names[i]+'_prop.csv')
  proportions.append(df)

# %%
# ------------------------------- #
# CALCULATE CONFIGURATION METRICS #
# ------------------------------- #

config = []

for i in range(len(names)):
  df = SpatioTemporalAnalysis.compute_landscape_metrics_df(temporal_group[i], metrics = ['contagion', 'largest_patch_index'])
  df.to_csv('Drainage_analysis/datasets/land_use/configuration/'+names[i]+'_configuration.csv')
  config.append(df)

# %%
# ----------------------------------------------------------------- #
# Put class proportions in the same format as configuration metrics #
# ----------------------------------------------------------------- #

# Import csv files into a list of dataframes

files = sorted(glob.glob('Drainage_analysis/datasets/land_use/proportions/*_prop.csv'))
files_config = sorted(glob.glob('Drainage_analysis/datasets/land_use/configuration/*_configuration.csv'))
names = list(sorted(shp_file['Name']))

proportions = []
for i in files:
  data = pd.read_csv(i)
  proportions.append(data)
config = []
for i in files_config:
  data = pd.read_csv(i)
  config.append(data)

#Create new dataframes in same format as configuration metrics

new_df = []
for i in range(len(proportions)):
  df = pd.DataFrame(years, columns=['dates'])
  prop = proportions[i]
  df['DrainName'] = names[i]
  df['class1_urban'] = prop['proportion_of_landscape'][prop['class_val'] == 1]
  df['class2_crops'] = prop['proportion_of_landscape'][prop['class_val'] == 2].values
  df = df.fillna(0)
  new_df.append(df)

# %%
## ------------------------------------------ ##
## CALCULATE CHANGE IN URBAN AREA FOR MAPPING ##
## ------------------------------------------ ##

prop = pd.concat(new_df)

change = prop.groupby('DrainName', as_index=False).class1_urban.agg(['min','max']).reset_index().fillna(0)
change['urb_change'] = change['max']-change['min']
change.to_csv('Drainage_analysis/datasets/land_use/proportions/change.csv')

# %%
## -------------------- ##
## MERGE TWO DATAFRAMES ##
## -------------------- ##

merged = []

for i in range(len(new_df)):
  df = new_df[i]
  con = config[i]
  df_merge = df.merge(con, on='dates', how='left')
  display(df_merge)
  df_merge.to_csv('Drainage_analysis/datasets/output_files/land_cover/'+names[i]+'.csv')
  merged.append(df_merge)
